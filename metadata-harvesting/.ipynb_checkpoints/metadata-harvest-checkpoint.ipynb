# %%
import requests
import json

# %%
#instructions: https://developers.zenodo.org/#records

response = requests.get('https://zenodo.org/api/records',
                        params={'communities': 'nantucketbiodiversity',
                                'access_token': 'FILL IN ACCESS TOKEN HERE'})
len(response.json())
# Out:
# 3

# %%
print(response.json())
# Out:
# {'aggregations': {'access_right': {'buckets': [{'doc_count': 25, 'key': 'open'}], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 0}, 'communities': {'buckets': [{'doc_count': 25, 'key': 'nantucketbiodiversity'}], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 0}, 'file_type': {'buckets': [{'doc_count': 22, 'key': 'pdf'}, {'doc_count': 6, 'key': 'csv'}, {'doc_count': 1, 'key': 'r'}], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 0}, 'keywords': {'buckets': [{'doc_count': 21, 'key': 'animalia'}, {'doc_count': 20, 'key': 'nantucket'}, {'doc_count': 15, 'key': 'invertebrates'}, {'doc_count': 15, 'key': 'nbi grant'}, {'doc_count': 15, 'key': 'species survey'}, {'doc_count': 9, 'key': 'tuckernuck'}, {'doc_count': 7, 'key': 'pitfall traps'}, {'doc_count': 6, 'key': 'field observation'}, {'doc_count': 6, 'key': 'hand collection'}, {'doc_count': 6, 'key': 'muskeget'}], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 108}, 'type': {'buckets': [{'doc_count': 19, 'key': 'publication', 'subtype': {'buckets': [{'doc_count': 19, 'key': 'report'}], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 0}}, {'doc_count': 6, 'key': 'dataset', 'subtype': {'buckets': [], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 0}}], 'doc_count_error_upper_bound': 0, 'sum_other_doc_count': 0}}, 'hits': {'hits': [{'conceptdoi': '10.5281/zenodo.3925864', 'conceptrecid': '3925864', 'created': '2020-07-01T16:38:47.371842+00:00', 'doi': '10.5281/zenodo.3925865', 'files': [{'bucket': '11191b48-ff79-43d2-8c0d-a31f939ecb78', 'checksum': 'md5:356aa55fdcf2d25439c5f838091f5272', 'key': 'mckenna-foster-et-al-nbi-report-2010.pdf', 'links': {'self': 'https://zenodo.org/api/files/11191b48-ff79-43d2-8c0d-a31f939ecb78/mckenna-foster-et-al-nbi-report-2010.pdf'}, 'size': 592080, 'type': 'pdf'}], 'id': 3925865, 'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.3925865.svg', 'bucket': 'https://zenodo.org/api/files/11191b48-ff79-43d2-8c0d-a31f939ecb78', 'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.3925864.svg', 'conceptdoi': 'https://doi.org/10.5281/zenodo.3925864', 'doi': 'https://doi.org/10.5281/zenodo.3925865', 'html': 'https://zenodo.org/record/3925865', 'latest': 'https://zenodo.org/api/records/3925865', 'latest_html': 'https://zenodo.org/record/3925865', 'self': 'https://zenodo.org/api/records/3925865'}, 'metadata': {'access_right': 'open', 'access_right_category': 'success', 'communities': [{'id': 'nantucketbiodiversity'}], 'creators': [{'affiliation': 'Maria Mitchell Association', 'name': 'Mckenna-Foster, Andrew', 'orcid': '0000-0001-7641-6588'}, {'affiliation': 'Maria Mitchell Association', 'name': 'Comeau Beaton, Cheryl'}, {'name': 'Millman, Lawrence'}], 'description': '<p>Report submitted in fulfillment of a 2009 Nantucket Biodiversity Initiative grant.</p>\n\n<p>The American millipede N. americanus/annularis complex is common on Tuckernuck Island, Massachusetts. Each summer numerous headless millipede bodies are found partly alive on the trails and roads of Tuckernuck; the cause of these decapitations remains unknown. We traveled to the island three times between June and October 2009 to measure headless millipedes and attempt to catch a decapitation on digital video We did not see any evidence of millipede predation In 97 minutes of video but we did record birds foraging on the roads for 6.7% of the video time. We present measurement data for injured and headless millipedes found during 2009 and note the occurrence of parasitic Myriophora flies harassing millipedes. Our data do not explain how or why millipedes are found headless on the island but present several possibilities for future work as well as important baseline observations to aid future investigators.</p>', 'doi': '10.5281/zenodo.3925865', 'keywords': ['tuckernuck', 'field observation', 'digital recording', 'animalia', 'NBI Grant', 'predation study', 'invertebrates'], 'language': 'eng', 'license': {'id': 'CC-BY-4.0'}, 'pub ...

# %%
metadata = json.loads(response.text)

# %%
#One way to get visualizations to the web: https://www.freecodecamp.org/news/how-to-create-auto-updating-data-visualizations-in-python-with-matplotlib-and-aws/
